# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gopinath04-R/gopinath-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Lane: Refresh / Content Opportunity Scoring**
#
# I'm continuing with this lane because I already ran the starter pipeline (notebooks 01 and 02) and understand the `trend_direction`, `baseline_refresh_score`, and precision@K workflow. My question: which pages should be reviewed first for a content refresh, based on evidence of staleness, declining visibility, and demand — not a fixed hand-written rule?

# %%
# Confirming lane choice
print("Lane: Refresh / Content Opportunity Scoring")
print("Reusing the starter pipeline concepts from notebooks 01 & 02.")
# Out:
# Lane: Refresh / Content Opportunity Scoring
# Reusing the starter pipeline concepts from notebooks 01 & 02.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision:** Which pages to prioritize for a content refresh this cycle.
#
# **Who acts:** A content team member reviewing the top-ranked pages.
#
# **Cost of a wrong call:** If a page is wrongly flagged as "needs refresh," the team wastes editing time on a page that wasn't actually declining. If a truly declining page is missed, it keeps losing visibility silently until the next review cycle.

# %%
print("Decision: prioritize pages for refresh review")
print("Actor: content team reviewer")
print("Cost of false positive: wasted editing time")
print("Cost of false negative: continued silent traffic decline")
# Out:
# Decision: prioritize pages for refresh review
# Actor: content team reviewer
# Cost of false positive: wasted editing time
# Cost of false negative: continued silent traffic decline

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Loading the starter dataset to show why this lane matters right now.

# %%
import pandas as pd
df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
declining = (df["trend_direction"] == "down").sum()
stale = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"Total pages: {len(df)}")
print(f"Pages currently declining: {declining} ({declining/len(df)*100:.1f}%)")
print(f"Pages that are stale AND still getting traffic: {stale}")
# Out:
# Total pages: 30000
# Pages currently declining: 16262 (54.2%)
# Pages that are stale AND still getting traffic: 17

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can claim:** Observed patterns — which pages show declining trends, staleness, or low CTR relative to their position, based on the data. Directional signals for prioritization.
#
# **What I cannot claim:** That refreshing a page will cause traffic to recover (that needs a controlled experiment). I cannot claim to have discovered a Google ranking factor. My model only ranks review priority — it does not guarantee outcomes.

# %%
print("Claims: observed, directional, decision-support only")
print("Not claimed: causal recovery proof, Google algorithm discovery")
# Out:
# Claims: observed, directional, decision-support only
# Not claimed: causal recovery proof, Google algorithm discovery

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
